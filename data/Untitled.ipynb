# %%
import pandas as pd

# %%
df = pd.read_csv("polarization1995_data.csv")

# %%
df.columns += '_1995'

# %%
df = df.drop('Unnamed: 0_1995', axis=1)

# %%
df.to_csv('polarization1995_data.csv')

# %%
df_2000 = pd. read_csv("polarization2000_data.csv")
df_2004 = pd.read_csv("polarization2004_data.csv")
df_1995 = pd.read_csv("polarization1995_data.csv")

# %%
df_2000.columns += '_2000'
df_2004.columns += '_2004'

# %%
df_2000
# Out:
#     Unnamed: 0_2000  std_dev_age_2000  native_share_2000  \
# 0                 0         18.275323           0.958919
# 1                 1         18.773603           0.959739
# 2                 2         18.378665           0.923409
# 3                 3         18.756243           0.974206
# 4                 4         18.888780           0.972397
# 5                 5         18.180234           0.969923
# 6                 6         18.342758           0.952381
# 7                 7         19.189720           0.958635
# 8                 8         18.570539           0.959347
# 9                 9         18.821393           0.971787
# 10               10         19.155504           0.966463
#
#     education_variability_2000      nuts118nm_2000  job_variability_2000  \
# 0                        462.0       East Midlands                 462.0
# 1                        459.0     East of England                 459.0
# ...

# %%
df_2000 = df_2000.drop('Unnamed: 0_2000', axis=1)
df_2004 = df_2004.drop('Unnamed: 0_2004', axis=1)

# %%
df_1995
df_1995 = df_1995.drop('Unnamed: 0', axis=1)

# %%
df_1995
# Out:
#     std_dev_age_1995  native_share_1995  education_variability_1995  \
# 0          18.929772           0.946183                       399.0
# 1          18.511457           0.953883                       411.5
# 2          17.650852           0.938341                       445.5
# 3          18.640090           0.964623                       211.5
# 4          18.636682           0.955357                       559.5
# 5          18.132051           0.934602                       420.0
# 6          18.151452           0.946148                       668.0
# 7          19.026620           0.940828                       422.0
# 8          18.734239           0.947262                       246.0
# 9          18.253225           0.966460                       402.0
# 10         18.856288           0.967404                       429.0
#
#         nuts118nm_1995  job_variability_1995  frac_employed_1995  \
# 0        East Midlands                 399.0            0.446809
# ...

# %%
df_1995.to_csv('polarisation_1995.csv')
df_2000.to_csv('polarisation_2000.csv')
df_2004.to_csv('polarisation_2004.csv')
