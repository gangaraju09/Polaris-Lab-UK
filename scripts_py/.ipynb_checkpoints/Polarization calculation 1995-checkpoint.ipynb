# %% [markdown]
# # Polarization calculation 1995

# %%
import pandas as pd
import os
import time
import numpy as np

# %%
os.chdir(r"A:\UW-Madison\GIS SPRING 2023\Geog 575\Final_Project\SPSS_Processed\UKDA-5151-spss\spss\spss19")

# %%
df_residence = pd.read_csv(r"A:\UW-Madison\GIS SPRING 2023\Geog 575\Final_Project\SPSS_Processed\UKDA-5151-spss\spss\spss19\bhps_w5\eindresp.csv")
# Out:
# C:\Users\ramak\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,7,28,400,588,824,858,859,870,871,872,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,975,999,1001) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(list(df_residence.columns))
# Out:
# ['Unnamed: 0', 'ehid', 'epno', 'edoid', 'edoim', 'edoiy', 'eivsoih', 'eivsoim', 'eivlyr', 'eivievr', 'elknbrd', 'elkmove', 'elkmovy', 'eplnew', 'eplnowm', 'eplnowy', 'emovjb', 'emovjba', 'emovjbb', 'emovjbc', 'emovjbd', 'emovjbe', 'emovjbf', 'emovjbg', 'emovjbh', 'emovjbi', 'emovy1', 'emovy2', 'edoby', 'esex', 'ejbstat', 'eedlyr', 'eedendm', 'eedendy', 'eedtype', 'eqfx', 'eqfxa', 'eqfxb', 'eqfxc', 'eqfxd', 'eqfxe', 'eqfxf', 'eqfxg', 'eqfxh', 'eqfxi', 'eqfxj', 'eqfxk', 'eqfxl', 'eqfxm', 'eqfxn', 'eqfedx', 'eqfedxa', 'enqfexa', 'eqfedxb', 'enqfexb', 'eqfedxc', 'enqfexc', 'eqfedxd', 'eqfedxe', 'enqfexe', 'eqfedxf', 'enqfexf', 'eqfedxg', 'enqfexg', 'eqfedxh', 'enqfexh', 'eqfedxi', 'enqfexi', 'eqfedxj', 'enqfexj', 'eqfedxk', 'enqfexk', 'emlstat', 'emlchng', 'emlchm', 'emlchy', 'eyr2uk', 'erace', 'eschool', 'escend', 'esctype', 'escnow', 'efetype', 'efenow', 'efeend', 'eqfhas', 'eqfa', 'eqfb', 'eqfc', 'eqfd', 'eqfe', 'eqff', 'eqfg', 'eqfh', 'eqfi', 'eqfj', 'eqfk', 'eqfl', 'eqfm', 'eqfn', 'eqfed', 'eqfeda', 'enqfeda', 'eqfedb', 'enqfedb', 'eqfedc', 'enqfedc', 'eqfedd', 'enqfedd', 'eqfede', 'enqfede', 'eqfedf', 'enqfedf', 'eqfedg', 'enqfedg', 'eqfedh', 'enqfedh', 'eqfedi', 'enqfedi', 'eqfedj', 'enqfedj', 'eqfedk', 'enqfedk', 'eqfedl', 'enqfedl', 'eqfedm', 'enqfedm', 'eqfedn', 'enqfedn', 'eqfedo', 'enqfedo', 'eqfedp', 'enqfedp', 'eqfedq', 'enqfedq', 'eqfedr', 'enqfedr', 'eqfeds', 'enqfeds', 'ehlstat', 'ehlzest', 'ehldsbl', 'ehlprb', 'ehlprba', 'ehlprbb', 'ehlprbc', 'ehlprbd', 'ehlprbe', 'ehlprbf', 'ehlprbg', 'ehlprbh', 'ehlprbi', 'ehlprbj', 'ehlprbk', 'ehlprbl', 'ehlprbm', 'ehllt', 'ehllta', 'ehlltb', 'ehlltc', 'ehlltd', 'ehllte', 'ehlltw', 'ehlendw', 'ehlltwa', 'ehl2gp', 'exdts', 'enxdts', 'exdt1m', 'exdt2m', 'exdt3m', 'exdt1y', 'exdt2y', 'exdt3y', 'exdt1pl', 'exdt2pl', 'exdt3pl', 'ehosp', 'ehospd', 'ehospch', 'ehospnhs', 'ehlsv', 'ehlsva', 'ehlsvan', 'ehlsvaf', 'ehlsvb', 'ehlsvbn', 'ehlsvbf', 'ehlsvc', 'ehlsvcn', 'ehlsvcf', 'ehlsvd', 'ehlsvdn', 'ehlsvdf', 'ehlsve', 'ehlsven', 'ehlsvef', 'ehlsvf', 'ehlsvfn', 'ehlsvff', 'ehlsvg', 'ehlsvgn', 'ehlsvgf', 'ehlsvh', 'ehlsvhn', 'ehlsvhf', 'ehlsvi', 'ehlsvin', 'ehlsvif', 'ehlsvj', 'ehlsvjn', 'ehlsvjf', 'ehlsvk', 'ehlsvkn', 'ehlsvkf', 'ehlsvl', 'ehlsvln', 'ehlsvlf', 'ehlsvm', 'ehlsvmn', 'ehlsvmf', 'ehlck', 'ehlcka', 'ehlckan', 'ehlckb', 'ehlckbn', 'ehlckc', 'ehlckcn', 'ehlckd', 'ehlckdn', 'ehlcke', 'ehlcken', 'ehlckf', 'ehlckfn', 'ehlckg', 'ehlckgn', 'ehlckh', 'ehlckhn', 'ehlcki', 'ehlckin', 'esmoker', 'encigs', 'eophla', 'eophlb', 'eophlc', 'eaidhh', 'eaidhua', 'eaidhub', 'eaidhuc', 'eaidxhh', 'enaidxhh', 'eaidhu1', 'eaidhu2', 'eaidhrs', 'eivma', 'eivmb', 'eivmc', 'eivmd', 'eivme', 'ejbhas', 'ejboff', 'ejboffy', 'ejbterm', 'ejbsic', 'ejbsemp', 'ejbmngr', 'ejbsize', 'ejbhrs', 'ejbot', 'ejbotpd', 'ejbhrlk', 'ejbpl', 'ejbttwt', 'ejbttwm', 'ejbsat1', 'ejbsat2', 'ejbsat3', 'ejbsat4', 'ejbsat5', 'ejbsat6', 'ejbsat7', 'ejbsat', 'epaygl', 'epaygw', 'epaynl', 'epaynw', 'epayslp', 'epayusl', 'epayu', 'epayuw', 'epayug', 'epaydf1', 'epaydf2', 'epaydf3', 'epaydf4', 'epaydf5', 'epaydf6', 'epaydf7', 'epaydf8', 'ejbbgd', 'ejbbgm', 'ejbbgy', 'ejbbgly', 'ejbsect', 'ejbonus', 'ejbrise', 'etujbpl', 'etuin1', 'etuin2', 'ejbopps', 'ejbtime', 'epays', 'epaysw', 'epaysg', 'ejbpen', 'ejbpenm', 'epayly', 'epaylyw', 'epaylyg', 'ejsboss', 'ejssize', 'ejshrs', 'ejshrlk', 'ejstime', 'ejstype', 'ejsaccs', 'ejsprf', 'ejsprbm', 'ejsprby', 'ejsprem', 'ejsprey', 'ejspayl', 'ejspybm', 'ejspyby', 'ejspyem', 'ejspyey', 'ejspl', 'ejsttwt', 'ejsttwm', 'ejssat1', 'ejssat2', 'ejssat3', 'ejssat4', 'ejssat5', 'ejssat', 'ejsbgd', 'ejsbgm', 'ejsbgy', 'ejbed', 'ejbed1', 'ejbed2', 'ejbed3', 'ejbed4', 'ejbed5', 'ejbedq', 'ejbedp1', 'erach12', 'ejbchc1', 'ejbchc2', 'ejbchc3', 'expchcf', 'expchc', 'ehuxpch', 'ehunurs', 'ejulk1', 'ejulk4', 'ejulkjb', 'ejuspec', 'ejuhrsx', 'ejupayx', 'ejupayl', 'ejuhrsl', 'eeaage', 'ejbub', 'ejbuby', 'ej2has', 'ej2semp', 'ej2hrs', 'ej2pay', 'ejbhha', 'ejbhhb', 'ejbhhc', 'ejbhhd', 'ejbhhe', 'ejbhhf', 'eivea', ' ...

# %%
# Loading variables of interest from 1995 BHPS dataset into dataframe
df_residence = df_residence[["eopsocc","eopsocd","eopsoce","efiyr","efetype","eage12","ejbstatt","eregion2", "eplbornc_cc"]]

# %%
# Dropping rows if they donot have any spatial information
df_residence = df_residence[~df_residence["eregion2"].isin(["don't know", "inapplicable", "missing or wild", "refused"])]

# %%
# To view columns
df_residence.head()
# Out:
#               eopsocc              eopsocd             eopsoce  \
# 0  proxy and/or phone   proxy and/or phone  proxy and/or phone
# 1               Agree             Disagree            Disagree
# 2               Agree                Agree            Disagree
# 3               Agree  Not agree, disagree   Strongly disagree
# 4  proxy and/or phone   proxy and/or phone  proxy and/or phone
#
#                 efiyr       efetype  eage12            ejbstatt eregion2  \
# 0  proxy and/or phone  inapplicable    58.0  proxy and/or phone   London
# 1         75532.59375  inapplicable    61.0      In paid employ   London
# 2      514.2568359375  inapplicable    53.0       Self employed   London
# 3                 0.0  inapplicable    16.0    FT studt, school   London
# 4  proxy and/or phone  inapplicable    50.0  proxy and/or phone   London
#
#           eplbornc_cc
# 0  proxy and/or phone
# 1        inapplicable
# 2        inapplicable
# 3           australia
# 4  proxy and/or phone

# %%
# create an empty dataframe
output_df = pd.DataFrame()

# Group the dataframe by county and calculate standard deviation of age : "aage12"
output_df["std_dev_age"] = df_residence.groupby("eregion2")["eage12"].agg("std")

# Group the dataframe by county and number of people born in UK : "eplbornc_cc"
output_df["born"] = df_residence.groupby("eregion2")["eplbornc_cc"]

# Assuming inapplicable as people born in UK to all others
def native_share(x):
    pop_count = list(x["born"][1])
    native_count = pop_count.count("inapplicable")/len(pop_count)
    return native_count

# calculating fraction of natives in each county
output_df["native_share"] = output_df.apply(lambda x: native_share(x), axis = 1)

# Dropping "born" groupby column
output_df = output_df.drop(columns = ["born"], axis = 1)

# Creating efetype_dict based on PDF from 1995 BHPS data
efetype_dict = {"Nursing school etc" : 1, "College of f educ" : 2, "Other trng establmnt" : 3, "Polytechnic" : 4, \
                "University" : 5, "None of the above" : 7, "don't know" : -1, "missing or wild" : -9, \
                    "inapplicable" : -8, "proxy and/or phone" : -7, "refused" : -2}


# Create a new column "efetype_encoded" in the dataframe by replacing the values with encoded values from the dictionary
df_residence["efetype_encoded"] = df_residence["efetype"].replace(efetype_dict)

# Group the dataframe by county and "efetype_encoded"
output_df["education"] = df_residence.groupby("eregion2")["efetype_encoded"]

# function to calculate dissimilarity in education
def dissimilarity_education(x):
    # loads tuple element into job
    job = x["education"][1]
    # loads frequency of each education type in county as list
    freq = list(job.value_counts())
    # calculates total number of groups
    s = len(freq)
    dissim_index = 0
    for i in freq:
        # formula of dissimilarity index
        dissim_index += 0.5 * abs(i-(1/s))
    return dissim_index

def region_name(x):
    return x["education"][0]

output_df["education_variability"] = output_df.apply(lambda x: dissimilarity_education(x), axis = 1)
output_df["region_name"] = output_df.apply(lambda x: region_name(x), axis = 1)

# Dropping "education" groupby column
output_df = output_df.drop(columns = ["education"], axis = 1)

# Creating ejbstatt_dict based on PDF from 1995 BHPS data
ejbstatt_dict = {"Self employed" : 1, "In paid employ" : 2, "Unemployed" : 3, "Retired" : 4, "Maternity leave" : 5, \
                    "Family care" : 6,  "FT studt, school" : 7, " LT sick, disabld" : 8, \
                    "Govt trng scheme" : 9, "Something else" : 10, "don't know" : -1, "missing or wild" : -9, \
                    "inapplicable" : -8, "proxy" : -7, "refused" : -2}


# Create a new column "ejbstatt_encoded" in the dataframe by replacing the values with encoded values from the dictionary
df_residence["ejbstatt_encoded"] = df_residence["ejbstatt"].replace(ejbstatt_dict)

# Group the dataframe by county and calculate the mean and standard deviation of the encoded values
output_df["job"] = df_residence.groupby("eregion2")["ejbstatt_encoded"]

# function to calculate dissimilarity in job
def dissimilarity_job(x):
    job = x["job"][1]
    freq = list(job.value_counts())
    s = len(freq)
    dissim_index = 0
    for i in freq:
        dissim_index += 0.5 * abs(i-(1/s))
    return dissim_index

# function to calculate fraction of employed people within each county
def frac_employed(x):
    job = list(x["job"][1])
    frac_emp = (job.count(2)/len(job))
    return frac_emp

output_df["job_variability"] = output_df.apply(lambda x: dissimilarity_job(x), axis = 1)
output_df ["frac_employed"] = output_df.apply(lambda x: frac_employed(x), axis = 1)

# Dropping "education" groupby column
output_df = output_df.drop(columns = ["job"], axis = 1)

# replacing all Not-A-Number cases to zero i.e., proxy values
df_residence["efiyr"] = df_residence["efiyr"].replace("proxy and/or phone",0)

# Group the dataframe by county and calculate median based on self-reported annual income: "efiyr"
output_df["median_income"] = df_residence.groupby("eregion2")["efiyr"].agg(["median"])

# convert "efiyr" column to float data type
df_residence["efiyr"] = df_residence["efiyr"].astype("float32")

# group incomes by county
output_df["income"] = df_residence.groupby("eregion2")["efiyr"]

def gini_index(x):
    data = list(x["income"][1])
    # sort the data in ascending order
    sorted_data = np.sort(data)
    # calculate the cumulative sum of the sorted data
    cumsum_data = np.cumsum(sorted_data)
    # calculate the Lorenz curve values
    lorenz_curve = cumsum_data / cumsum_data[-1]
    # calculate the area under the Lorenz curve
    area_lorenz_curve = np.trapz(lorenz_curve, dx=1/len(data))
    # calculate the Gini index
    gini_index = 1 - 2 * area_lorenz_curve
    return gini_index

output_df["gini_index"] = output_df.apply(lambda x : gini_index(x), axis = 1)

# Drop "income" groupby column
output_df = output_df.drop(columns = ["income"], axis = 1)

output_df
# Out:
#                     std_dev_age  native_share  education_variability  \
# eregion2
# East Midlands         18.929772      0.946183                  399.0
# East of England       18.511457      0.953883                  411.5
# London                17.650852      0.938341                  445.5
# North East            18.640090      0.964623                  211.5
# North West            18.636682      0.955357                  559.5
# Scotland              18.132051      0.934602                  420.0
# South East            18.151452      0.946148                  668.0
# South West            19.026620      0.940828                  422.0
# Wales                 18.734239      0.947262                  246.0
# West Midlands         18.253225      0.966460                  402.0
# Yorkshire & Humber    18.856288      0.967404                  429.0
#
#                            region_name  job_variability  frac_employed  \
# eregion2
# East Midlands            East Midlands            399.0       0.446809
# East of England        East of England            411.5       0.470874
# London                          London            445.5       0.487668
# North East                  North East            211.5       0.464623
# North West                  North West            559.5       0.468750
# Scotland                      Scotland            420.0       0.475624
# South East                  South East            668.0       0.504114
# South West                  South West            422.0       0.455621
# Wales                            Wales            246.0       0.399594
# West Midlands            West Midlands            402.0       0.475776
# Yorkshire & Humber  Yorkshire & Humber            429.0       0.462165
#
#                     median_income  gini_index
# eregion2
# East Midlands         6427.445312    0.485968
# East of England       7721.132812    0.497099
# London                8279.160645    0.520353
# North East            6390.706543    0.455352
# North West            6927.100586    0.496123
# Scotland              6681.736328    0.497527
# South East            7912.114746    0.494032
# South West            6339.334961    0.494527
# Wales                 6077.859863    0.458942
# West Midlands         6500.000000    0.484510
# Yorkshire & Humber    6588.619141    0.471141

# %%
# Define the dictionary to encode the "eopsocc" column which is Statement 1 (S1)
# S1: "Private enterprise is the best way to solve Britain’s economic problems."
eopsocc_dict = {"Strongly agree": 2,"Agree":1, "Not agree, disagree": 0 , "Disagree":-1 , "Strongly disagree": -2,
                "don't know": -3 , "missing or wild": -3, "inapplicable":-3,
                "proxy and/or phone":-3, "refused":-3}

# Create a new column "eopsocc_encoded" in the dataframe by replacing the values with encoded values from the dictionary
df_residence["eopsocc_encoded"] = df_residence["eopsocc"].replace(eopsocc_dict)

#remove -3 valued rows from df_residence[jopsocc_encoded]
df_residence = df_residence[df_residence['eopsocc_encoded'] != -3]

# Political polarization measurement by Lindqvist and Ostling (2010)
output_df["Lindqvist_Ostling_S1"] = df_residence.groupby("eregion2")["eopsocc_encoded"].agg(["var"])

# Create new columns based on absolute sum of encoded values of opinions and counts
output_df["abs_sum"] = df_residence.groupby("eregion2")["eopsocc_encoded"].apply(lambda x: x.abs().sum())
output_df["counts"] = df_residence.groupby("eregion2")["eopsocc_encoded"].apply(lambda x: x.count())

# Political polarization measurement by Abramowitz and Saunders (2008)
output_df["Abramowitz_Saunders_S1"] = output_df.apply(lambda x: x["abs_sum"]/x["counts"], axis = 1)

output_df = output_df.drop(columns = ["abs_sum", "counts"], axis = 1)

# Group the dataframe by county and eopsocc_encoded values
output_df["dkp"] = df_residence.groupby("eregion2")["eopsocc_encoded"]

# Political polarization measurement by Duca and Saving (2016)
def duca_saving(x):
    county_tuple = x["dkp"]
    freq = list(county_tuple[1].value_counts())
    val = list(county_tuple[1].unique())
    norm_freq = [i/sum(freq) for i in freq]
    outer_sum = 0
    for i in range(len(norm_freq)):
        nkit = norm_freq[i]
        inner_sum = 0
        for j in range(len(norm_freq)):
            npit = norm_freq[j]
            dkp = abs(val[i] - val[j])
            inner_sum += npit*dkp
    outer_sum += (nkit**2)*inner_sum
    
    return outer_sum

output_df["Duca_Saving_S1"] = output_df.apply(lambda x: duca_saving(x)*1000, axis = 1)

# Drop "income" groupby column
output_df = output_df.drop(columns = ["dkp"], axis = 1)

output_df
# Out:
#                     std_dev_age  native_share  education_variability  \
# eregion2
# East Midlands         18.929772      0.946183                  399.0
# East of England       18.511457      0.953883                  411.5
# London                17.650852      0.938341                  445.5
# North East            18.640090      0.964623                  211.5
# North West            18.636682      0.955357                  559.5
# Scotland              18.132051      0.934602                  420.0
# South East            18.151452      0.946148                  668.0
# South West            19.026620      0.940828                  422.0
# Wales                 18.734239      0.947262                  246.0
# West Midlands         18.253225      0.966460                  402.0
# Yorkshire & Humber    18.856288      0.967404                  429.0
#
#                            region_name  job_variability  frac_employed  \
# eregion2
# East Midlands            East Midlands            399.0       0.446809
# East of England        East of England            411.5       0.470874
# London                          London            445.5       0.487668
# North East                  North East            211.5       0.464623
# North West                  North West            559.5       0.468750
# Scotland                      Scotland            420.0       0.475624
# South East                  South East            668.0       0.504114
# South West                  South West            422.0       0.455621
# Wales                            Wales            246.0       0.399594
# West Midlands            West Midlands            402.0       0.475776
# Yorkshire & Humber  Yorkshire & Humber            429.0       0.462165
#
#                     median_income  gini_index  Lindqvist_Ostling_S1  \
# eregion2
# East Midlands         6427.445312    0.485968              0.843213
# East of England       7721.132812    0.497099              0.853691
# London                8279.160645    0.520353              0.858060
# North East            6390.706543    0.455352              0.818051
# North West            6927.100586    0.496123              0.880076
# Scotland              6681.736328    0.497527              0.874789
# South East            7912.114746    0.494032              0.785931
# South West            6339.334961    0.494527              0.854575
# Wales                 6077.859863    0.458942              0.844509
# West Midlands         6500.000000    0.484510              0.855368
# Yorkshire & Humber    6588.619141    0.471141              0.810283
#
#                     Abramowitz_Saunders_S1  Duca_Saving_S1
# eregion2
# East Midlands                     0.726141        1.394025
# East of England                   0.725131        1.004499
# London                            0.761139        0.376180
# North East                        0.719794        1.236752
# North West                        0.776119        0.954488
# Scotland                          0.808540        0.540013
# South East                        0.677075        0.894840
# South West                        0.723179        2.122681
# Wales                             0.803204        0.744511
# West Midlands                     0.724658        1.605215
# Yorkshire & Humber                0.735589        0.855864

# %%
# Define the dictionary to encode the "eopsocd" column which is Statement 2 (S2)
# S2: "Major public services and industries ought to be in state ownership."

eopsocd_dict = {"Strongly agree": 2,"Agree":1, "Not agree, disagree": 0 , "Disagree":-1 , "Strongly disagree": -2,
                "don't know": -3, "missing or wild": -3, "inapplicable":-3, "proxy and/or phone":-3, "refused":-3}

# Create a new column "eopsocc_encoded" in the dataframe by replacing the values with encoded values from the dictionary
df_residence["eopsocd_encoded"] = df_residence["eopsocd"].replace(eopsocd_dict)

#remove -3 valued rows from df_residence[jopsocc_encoded]
df_residence = df_residence[df_residence['eopsocd_encoded'] != -3]

# Political polarization measurement by Lindqvist and Ostling (2010)
output_df["Lindqvist_Ostling_S2"] = df_residence.groupby("eregion2")["eopsocd_encoded"].agg(["var"])

# Create new columns based on absolute sum of encoded values of opinions and counts
output_df["abs_sum"] = df_residence.groupby("eregion2")["eopsocd_encoded"].apply(lambda x: x.abs().sum())
output_df["counts"] = df_residence.groupby("eregion2")["eopsocd_encoded"].apply(lambda x: x.count())

# Political polarization measurement by Abramowitz and Saunders (2008)
output_df["Abramowitz_Saunders_S2"] = output_df.apply(lambda x: x["abs_sum"]/x["counts"], axis = 1)

output_df = output_df.drop(columns = ["abs_sum", "counts"], axis = 1)

# Group the dataframe by county and aopsocc_encoded values
output_df["dkp"] = df_residence.groupby("eregion2")["eopsocd_encoded"]

# Political polarization measurement by Duca and Saving (2016)
def duca_saving(x):
    county_tuple = x["dkp"]
    freq = list(county_tuple[1].value_counts())
    val = list(county_tuple[1].unique())
    norm_freq = [i/sum(freq) for i in freq]
    outer_sum = 0
    for i in range(len(norm_freq)):
        nkit = norm_freq[i]
        inner_sum = 0
        for j in range(len(norm_freq)):
            npit = norm_freq[j]
            dkp = abs(val[i] - val[j])
            inner_sum += npit*dkp
    outer_sum += (nkit**2)*inner_sum
    
    return outer_sum

output_df["Duca_Saving_S2"] = output_df.apply(lambda x: duca_saving(x), axis = 1)

# Drop "income" groupby column
output_df = output_df.drop(columns = ["dkp"], axis = 1)

# %%
# Define the dictionary to encode the "eopsocd" column which is Statement 3 (S3)
# S3: "It is the government’s responsibility to provide a job for everyone who wants one."

eopsoce_dict = {"Strongly agree": 2,"Agree":1, "Not agree, disagree": 0 , "Disagree":-1 , "Strongly disagree": -2,
                "don't know": -3 , "missing or wild": -3, "inapplicable":-3, "proxy and/or phone":-3, "refused":-3}

# Create a new column "eopsocd_encoded" in the dataframe by replacing the values with encoded values from the dictionary
df_residence["eopsoce_encoded"] = df_residence["eopsoce"].replace(eopsoce_dict)

#remove -3 valued rows from df_residence[jopsocc_encoded]
df_residence = df_residence[df_residence['eopsoce_encoded'] != -3]

# Political polarization measurement by Lindqvist and Ostling (2010)
output_df["Lindqvist_Ostling_S3"] = df_residence.groupby("eregion2")["eopsoce_encoded"].agg(["var"])

# Create new columns based on absolute sum of encoded values of opinions and counts
output_df["abs_sum"] = df_residence.groupby("eregion2")["eopsoce_encoded"].apply(lambda x: x.abs().sum())
output_df["counts"] = df_residence.groupby("eregion2")["eopsoce_encoded"].apply(lambda x: x.count())

# Political polarization measurement by Abramowitz and Saunders (2008)
output_df["Abramowitz_Saunders_S3"] = output_df.apply(lambda x: x["abs_sum"]/x["counts"], axis = 1)

output_df = output_df.drop(columns = ["abs_sum", "counts"], axis = 1)

# Group the dataframe by county and eopsocc_encoded values
output_df["dkp"] = df_residence.groupby("eregion2")["eopsoce_encoded"]

# Political polarization measurement by Duca and Saving (2016)
def duca_saving(x):
    county_tuple = x["dkp"]
    freq = list(county_tuple[1].value_counts())
    val = list(county_tuple[1].unique())
    norm_freq = [i/sum(freq) for i in freq]
    outer_sum = 0
    for i in range(len(norm_freq)):
        nkit = norm_freq[i]
        inner_sum = 0
        for j in range(len(norm_freq)):
            npit = norm_freq[j]
            dkp = abs(val[i] - val[j])
            inner_sum += npit*dkp
    outer_sum += (nkit**2)*inner_sum
    
    return outer_sum

output_df["Duca_Saving_S3"] = output_df.apply(lambda x: duca_saving(x)*1000, axis = 1)

# Drop "income" groupby column
output_df = output_df.drop(columns = ["dkp"], axis = 1)

output_df
# Out:
#                     std_dev_age  native_share  education_variability  \
# eregion2
# East Midlands         18.929772      0.946183                  399.0
# East of England       18.511457      0.953883                  411.5
# London                17.650852      0.938341                  445.5
# North East            18.640090      0.964623                  211.5
# North West            18.636682      0.955357                  559.5
# Scotland              18.132051      0.934602                  420.0
# South East            18.151452      0.946148                  668.0
# South West            19.026620      0.940828                  422.0
# Wales                 18.734239      0.947262                  246.0
# West Midlands         18.253225      0.966460                  402.0
# Yorkshire & Humber    18.856288      0.967404                  429.0
#
#                            region_name  job_variability  frac_employed  \
# eregion2
# East Midlands            East Midlands            399.0       0.446809
# East of England        East of England            411.5       0.470874
# London                          London            445.5       0.487668
# North East                  North East            211.5       0.464623
# North West                  North West            559.5       0.468750
# Scotland                      Scotland            420.0       0.475624
# South East                  South East            668.0       0.504114
# South West                  South West            422.0       0.455621
# Wales                            Wales            246.0       0.399594
# West Midlands            West Midlands            402.0       0.475776
# Yorkshire & Humber  Yorkshire & Humber            429.0       0.462165
#
#                     median_income  gini_index  Lindqvist_Ostling_S1  \
# eregion2
# East Midlands         6427.445312    0.485968              0.843213
# East of England       7721.132812    0.497099              0.853691
# London                8279.160645    0.520353              0.858060
# North East            6390.706543    0.455352              0.818051
# North West            6927.100586    0.496123              0.880076
# Scotland              6681.736328    0.497527              0.874789
# South East            7912.114746    0.494032              0.785931
# South West            6339.334961    0.494527              0.854575
# Wales                 6077.859863    0.458942              0.844509
# West Midlands         6500.000000    0.484510              0.855368
# Yorkshire & Humber    6588.619141    0.471141              0.810283
#
#                     Abramowitz_Saunders_S1  Duca_Saving_S1  \
# eregion2
# East Midlands                     0.726141        1.394025
# East of England                   0.725131        1.004499
# London                            0.761139        0.376180
# North East                        0.719794        1.236752
# North West                        0.776119        0.954488
# Scotland                          0.808540        0.540013
# South East                        0.677075        0.894840
# South West                        0.723179        2.122681
# Wales                             0.803204        0.744511
# West Midlands                     0.724658        1.605215
# Yorkshire & Humber                0.735589        0.855864
#
#                     Lindqvist_Ostling_S2  Abramowitz_Saunders_S2  \
# eregion2
# East Midlands                   1.008246                0.852113
# East of England                 0.977064                0.828457
# London                          0.984581                0.873897
# North East                      0.978367                0.837270
# North West                      1.038682                0.899288
# Scotland                        0.962221                0.874471
# South East                      0.919018                0.800664
# South West                      1.007488                0.833784
# Wales                           1.055019                0.908879
# West Midlands                   0.997036                0.846797
# Yorkshire & Humber              0.885666                0.830573
#
#                     Duca_Saving_S2  Lindqvist_Ostling_S3  \
# eregion2
# East Midlands             0.001214              1.131366
# East of England           0.000922              1.089602
# London                    0.000884              1.188591
# North East                0.001336              0.992494
# North West                0.001155              1.091857
# Scotland                  0.000955              1.139900
# South East                0.000520              1.080334
# South West                0.002341              1.048865
# Wales                     0.001657              1.016852
# West Midlands             0.000665              1.051652
# Yorkshire & Humber        0.000352              1.085663
#
#                     Abramowitz_Saunders_S3  Duca_Saving_S3
# eregion2
# East Midlands                     0.949153        1.878866
# East of England                   0.922667        2.041536
# London                            0.961929        3.195147
# North East                        0.950000        0.161722
# North West                        0.967280        1.398335
# Scotland                          0.988701        1.264510
# South East                        0.919234        1.218511
# South West                        0.900950        1.723318
# Wales                             1.011737        1.629828
# West Midlands                     0.914566        1.975061
# Yorkshire & Humber                0.928480        1.717026

# %%
output_df.reset_index(drop=True, inplace=True)
output_df
# Out:
#     std_dev_age  native_share  education_variability         region_name  \
# 0     18.929772      0.946183                  399.0       East Midlands
# 1     18.511457      0.953883                  411.5     East of England
# 2     17.650852      0.938341                  445.5              London
# 3     18.640090      0.964623                  211.5          North East
# 4     18.636682      0.955357                  559.5          North West
# 5     18.132051      0.934602                  420.0            Scotland
# 6     18.151452      0.946148                  668.0          South East
# 7     19.026620      0.940828                  422.0          South West
# 8     18.734239      0.947262                  246.0               Wales
# 9     18.253225      0.966460                  402.0       West Midlands
# 10    18.856288      0.967404                  429.0  Yorkshire & Humber
#
#     job_variability  frac_employed  median_income  gini_index  \
# 0             399.0       0.446809    6427.445312    0.485968
# 1             411.5       0.470874    7721.132812    0.497099
# 2             445.5       0.487668    8279.160645    0.520353
# 3             211.5       0.464623    6390.706543    0.455352
# 4             559.5       0.468750    6927.100586    0.496123
# 5             420.0       0.475624    6681.736328    0.497527
# 6             668.0       0.504114    7912.114746    0.494032
# 7             422.0       0.455621    6339.334961    0.494527
# 8             246.0       0.399594    6077.859863    0.458942
# 9             402.0       0.475776    6500.000000    0.484510
# 10            429.0       0.462165    6588.619141    0.471141
#
#     Lindqvist_Ostling_S1  Abramowitz_Saunders_S1  Duca_Saving_S1  \
# 0               0.843213                0.726141        1.394025
# 1               0.853691                0.725131        1.004499
# 2               0.858060                0.761139        0.376180
# 3               0.818051                0.719794        1.236752
# 4               0.880076                0.776119        0.954488
# 5               0.874789                0.808540        0.540013
# 6               0.785931                0.677075        0.894840
# 7               0.854575                0.723179        2.122681
# 8               0.844509                0.803204        0.744511
# 9               0.855368                0.724658        1.605215
# 10              0.810283                0.735589        0.855864
#
#     Lindqvist_Ostling_S2  Abramowitz_Saunders_S2  Duca_Saving_S2  \
# 0               1.008246                0.852113        0.001214
# 1               0.977064                0.828457        0.000922
# 2               0.984581                0.873897        0.000884
# 3               0.978367                0.837270        0.001336
# 4               1.038682                0.899288        0.001155
# 5               0.962221                0.874471        0.000955
# 6               0.919018                0.800664        0.000520
# 7               1.007488                0.833784        0.002341
# 8               1.055019                0.908879        0.001657
# 9               0.997036                0.846797        0.000665
# 10              0.885666                0.830573        0.000352
#
#     Lindqvist_Ostling_S3  Abramowitz_Saunders_S3  Duca_Saving_S3
# 0               1.131366                0.949153        1.878866
# 1               1.089602                0.922667        2.041536
# 2               1.188591                0.961929        3.195147
# 3               0.992494                0.950000        0.161722
# 4               1.091857                0.967280        1.398335
# 5               1.139900                0.988701        1.264510
# 6               1.080334                0.919234        1.218511
# 7               1.048865                0.900950        1.723318
# 8               1.016852                1.011737        1.629828
# 9               1.051652                0.914566        1.975061
# 10              1.085663                0.928480        1.717026

# %%
output_df.to_csv(r"C:\Users\ramak\Desktop\Geog573_Lab\Geog_575_final_project\Final_output\polarization1995_data.csv")
